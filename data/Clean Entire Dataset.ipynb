# %%
import os
import csv
import pandas as pd
import numpy as np
import glob
# preprocess!
import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import WhitespaceTokenizer

tokenizer = WhitespaceTokenizer()
stop_words = set(stopwords.words('english'))
stop_words.update(['rt'])  # remove the retweet tag!

stemmer = SnowballStemmer("english")

import re

import sys
import time

import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
def merge_sents(sent):
    return ' '.join(sent)

# %%
def remove_links_and_html(sentence):
    sentence = re.sub(r'http\S+', '', sentence)
    sentence = re.sub(r'<[^<]+?>', '', sentence)

    return sentence

def remove_punct(sentence): #function to clean the word of any punctuation or special characters
    cleaned = re.sub(r'[?|!|\'|"|]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    cleaned = cleaned.strip()
    cleaned = cleaned.replace("\n"," ")
    return cleaned

def remove_mentions(sentence):
    # keep the @ to check for mentions among separate groups
    return re.sub(r'@#?\b\w\w+\b', '@', sentence)

def valid_token(tok):
    if '#' in tok:
        # make sure the hashtag is alphanumeric (avoiding arabic etc)
        nohash = tok[1:]
        is_latin = re.sub('[^0-9a-zA-Z]+', '', nohash) == nohash
        if is_latin:
            return tok
        else:
            return ''
    non_stop = tok not in stop_words
    no_rt = 'rt' not in tok
    is_latin = re.sub('[^0-9a-zA-Z]+', '', tok) == tok
    return is_latin and non_stop

def clean_stopwords(sentence):
    tokens = tokenizer.tokenize(sentence)
    return ' '.join([t for t in tokens if valid_token(t)])
        
def stem(sentence):
    tokens = tokenizer.tokenize(sentence)
    tokens = [stemmer.stem(t) for t in tokens]
    return ' '.join([t for t in tokens if valid_token(t)])

def empty_to_nan(sentence):
    if len(sentence) < 1:
        return np.nan
    else:
        return sentence

def clean_all(s):
    #s = s.lower()
    s = remove_links_and_html(s)
    s = remove_punct(s)
    s = remove_mentions(s)
    s = clean_stopwords(s)
    # stemming is slow on loads of data, consider uncommenting on big sets.
    #s = stem(s)
    # finally, make sure we have no empty texts
    s = empty_to_nan(s)
    return s

# %%
samples = glob.glob(os.path.join(os.getcwd(), 'SPLIT') + '/*')
labels = pd.read_json('../data/labels.ndjson', lines=True)
for sample in samples:
    csvname = 'SPLIT/' + sample[-6:] + '.csv'
    print(csvname)
    print(sample)
    df = pd.read_json(sample, lines=True)
    combined = pd.merge(df, labels, on='id')
    #combined = combined.drop(columns=['id'])  # no need for any non-label data
    combined['text'] = combined['text'].apply(merge_sents)
    combined = combined.dropna()
    print(combined.head())
    del df
    
    start = time.time()
    print('...cleaning')
    combined['text'] = combined['text'].str.lower()
    combined['text'] = combined['text'].apply(clean_all)
    end = time.time()
    print(end - start)

    # prune empty texts
    combined = combined.dropna()
    combined.to_csv(csvname, header=False, index=False)
# Out:
# SPLIT/feed00.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed00
#       id                                               text  birthyear  \
# 0  22704  Back at it with @americanidol looking for...he...       1984
# 1  46305  The last presidential election turned on fewer...       1961
# 2  30260  Angels ðŸ˜‡ \n@RobbieWilliams\nhttps://t.co/A6...       1989
# 3   4874  Listen to â€œShallowâ€�, â€œAlways Remember Us...       1986
# 4  41392  So happy for my island! Vote for Madeira, for ...       1985
#
#         fame  gender occupation
# 0  superstar  female  performer
# 1  superstar    male   politics
# 2  superstar  female  performer
# 3  superstar  female    creator
# 4  superstar    male    manager
# ...cleaning
# 159.29001307487488
# SPLIT/feed01.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed01
#       id                                               text  birthyear  \
# 0  48084  Paul Manafort is spending a lot of time with R...       1976
# 1  33848  theneighborhood Is going purple for #SpiritDay...       1969
# 2   3930  â€œCome fly with me...â€� @sixsenseszilpasyon ...       1986
# 3   9221  Yassssss ðŸ™ŒðŸ�½ https://t.co/egBF3OBKoY RT @...       1987
# 4   7380  RT @ChampionsLeague: ðŸ˜œ Cheeky \nâš¡ï¸� Elec...       1990
#
#         fame  gender occupation
# 0  superstar    male    creator
# 1  superstar  female  performer
# 2  superstar  female  performer
# 3  superstar  female  performer
# 4  superstar    male     sports
# ...cleaning
# 157.63805055618286
# SPLIT/feed02.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed02
#       id                                               text  birthyear  \
# 0  25541  RT @RealKevinNash: One for the ages. @HulkHoga...       1955
# 1  22004  https://t.co/4OhGAnHa40 @CeeVee12 @FIFAWorldCu...       1993
# 2  30510  Welp @VonMiller said they were going to KICK t...       1983
# 3  25939  Congrats @HCFBMaroons on your playoff-clinchin...       1988
# 4    972  #MartesDeLectura: En esta obra se exponen las ...       1940
#
#         fame gender occupation
# 0  superstar   male     sports
# 1  superstar   male     sports
# 2  superstar   male     sports
# 3  superstar   male     sports
# 4  superstar   male   politics
# ...cleaning
# 147.71796584129333
# SPLIT/feed03.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed03
#       id                                               text  birthyear  \
# 0  24811  RT @maliniagarwal: Honestly I'd like to take a...       1982
# 1   4969  RT @TeamQuetta: .@UmerAmin200 hit three sixes ...       1989
# 2  25912  My blood moon. https://t.co/MLpYviBu1S What a ...       1981
# 3  42277  Watch the former Jeff Beck Group bandmates per...       1944
# 4  20801  RT @FancyvandeVorst: Great opening @BioArtLab ...       1941
#
#         fame  gender occupation
# 0  superstar    male  performer
# 1  superstar    male     sports
# 2  superstar  female    creator
# 3  superstar    male  performer
# 4  superstar  female   politics
# ...cleaning
# 153.49035739898682
# SPLIT/feed04.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed04
#       id                                               text  birthyear  fame  \
# 0   5600  @ThatAnt_ @SupportAVFC He supports Tamworth FC...       1976  star
# 1  39940  @arielhelwani Bullshit, Ariel. This has to be ...       1987  star
# 2  20120  RT @WarrenBuffetIG: Here's what's cool:\n\n1 s...       1985  star
# 3  47634  @nhlaka_madwe @andileluck19 @sekojafta @Sibzma...       1995  star
# 4  36342  @Atlanta11286 @Thorkild_Olesen @kristeligt For...       1969  star
#
#    gender occupation
# 0    male  performer
# 1    male     sports
# 2  female  performer
# 3    male     sports
# 4    male   politics
# ...cleaning
# 165.79209637641907
# SPLIT/feed05.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed05
#       id                                               text  birthyear  fame  \
# 0  32709  RT @oren_cass: â€œIâ€™m for globalization and ...       1984  star
# 1    481  RT @5liveSport: Coming up from 7pm reactions t...       1965  star
# 2  17976  @Jarrodcroker @Uz_Khawaja What he get RT @AskK...       1986  star
# 3  44142  This is why itâ€™s so important to consume mul...       1970  star
# 4   1597  Clearly. The syllabus is biased against the co...       1980  star
#
#    gender occupation
# 0    male    creator
# 1    male     sports
# 2    male     sports
# 3  female    creator
# 4    male  performer
# ...cleaning
# 168.57082533836365
# SPLIT/feed06.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed06
#       id                                               text  birthyear  fame  \
# 0  16005  Holiday shoppers we are ready for you! Join me...       1954  star
# 1  34080  Oh yeah and itâ€™s *that* Sam Adams too https:...       1960  star
# 2   8834  What a great day last week at  pearl_valley vo...       1981  star
# 3  33561  @Thereal_Jnova I was late, but thanks for shar...       1990  star
# 4  32537  RT @AzmiShabana: What an honor to make it on t...       1972  star
#
#    gender occupation
# 0  female  performer
# 1    male   politics
# 2    male     sports
# 3    male     sports
# 4  female  performer
# ...cleaning
# 159.2499783039093
# SPLIT/feed07.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed07
#       id                                               text  birthyear  fame  \
# 0  33332  @EdLeafe Depends on the change and the tests. ...       1980  star
# 1  19853  RT â€œ@teagzwilkins: @tjrharley my lil champ h...       1978  star
# 2  31839  RT @JessJagmin: PSA: many of you may know, but...       1980  star
# 3  31300  three years today married to my best friend, i...       1983  star
# 4  31668  RT @BadgerMBB: Devin Harris... still working t...       1983  star
#
#   gender    occupation
# 0   male  professional
# 1   male        sports
# 2   male     performer
# 3   male       creator
# 4   male        sports
# ...cleaning
# 142.93576312065125
# SPLIT/feed08.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed08
#       id                                               text  birthyear  fame  \
# 0  42418  @LoretoStAlbans @Dickinson_Matt @pennyjoelson ...       1981  star
# 1   5679  Listening to the Steve Harvey morning show...e...       1979  star
# 2   5728  RT @levismokehouse: Have you taken advantage o...       1958  star
# 3  41709  Theyâ€™re people not a hurricane. https://t.co...       1982  star
# 4  10652  Very interesting https://t.co/MUinQ7pIvF @hlon...       1994  star
#
#    gender occupation
# 0  female    creator
# 1    male     sports
# 2    male  performer
# 3    male     sports
# 4    male     sports
# ...cleaning
# 139.8168659210205
# SPLIT/feed09.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed09
#       id                                               text  birthyear  fame  \
# 0   8515  @GK_arlen I mean. Germany. Anywhere in Germany...       1994  star
# 1  18393  RT @ICMMasters: Notts ICM winter academy start...       1980  star
# 2  42506  Come work with us https://t.co/uoMUgoVH45 RT @...       1969  star
# 3   3667  Okay, i know I'm a little late to the party wi...       1982  star
# 4  35525  @BabyLead Ya cuz I just lost 10 I hope u win y...       1991  star
#
#    gender occupation
# 0  female     sports
# 1    male     sports
# 2    male     sports
# 3    male  performer
# 4    male     sports
# ...cleaning
# 135.86516976356506
# SPLIT/feed10.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed10
#       id                                               text  birthyear  fame  \
# 0  38296  @DanHubbard @DanielMays9 Same. Absolute classi...       1979  star
# 1  46989  Awesome X https://t.co/1CTueHp6ai ðŸ’œ https:/...       1987  star
# 2  15833  Details for YORK tonight\nThe Clarence Club, 8...       1977  star
# 3    353  @moraisfilipe20 ðŸ‘ŠðŸ�»ðŸ‘ŠðŸ�»ðŸ‘ŠðŸ�»â�¤ï¸�...       1989  star
# 4  43410  My wife Peggy somehow seems to do it all! In a...       1959  star
#
#    gender occupation
# 0    male  performer
# 1  female  performer
# 2    male  performer
# 3    male     sports
# 4    male   politics
# ...cleaning
# 135.9061563014984
# SPLIT/feed11.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed11
#       id                                               text  birthyear  fame  \
# 0   4101  @derrycitylfc Yes Iâ€™d be delighted. DM me fo...       1982  star
# 1  44920  RT @DeniseNBCBoston: Yesterday's nor'easter di...       1966  star
# 2  11898  @Jigga2cal @CJMcCollum Maannn I needed to see ...       1990  star
# 3  22991  Congrats all the way from BC @TimHoustonNS! ht...       1976  star
# 4  20436  @realDonaldTrump You insight anger. You thrive...       1979  star
#
#    gender occupation
# 0  female     sports
# 1    male     sports
# 2    male     sports
# 3    male   politics
# 4  female    creator
# ...cleaning
# 128.2181360721588
# SPLIT/feed12.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed12
#       id                                               text  birthyear  fame  \
# 0  34984  @rizmc Remember when we first saw her Riz? Thi...       1972  star
# 1  44529  @heidiwillis @ABoveWill @ShoshanaRosenba @Lydi...       1977  star
# 2  16346  RT @moneyfm893: Listen to the full podcast as ...       1962  star
# 3   9469  happy 7th birthday to my beautiful little sist...       2000  star
# 4   9834  RT @bcliberals: Momentum is definitely buildin...       1957  star
#
#    gender occupation
# 0  female  performer
# 1  female    creator
# 2    male  performer
# 3  female    creator
# 4    male   politics
# ...cleaning
# 125.7715003490448
# SPLIT/feed13.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed13
#       id                                               text  birthyear  fame  \
# 0  12621  @retrontario I donâ€™t know where you folks ke...       1971  star
# 1   9732  RT @BNEFootball: Yesterday also saw @Thomas_TK...       1983  star
# 2  47944  I have been a long-timer admirer of Dave Snowd...       1969  star
# 3  16016  RT @SandraWalshWAG: @LiamDavie_1993 ðŸ’™this i...       1993  star
# 4    142  RT @_CarlosC7: Every week itâ€™s an inspiratio...       1993  star
#
#   gender occupation
# 0   male  performer
# 1   male     sports
# 2   male     sports
# 3   male     sports
# 4   male     sports
# ...cleaning
# 117.34927988052368
# SPLIT/feed14.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed14
#       id                                               text  birthyear  fame  \
# 0  43929  RT @billshortenmp: Foreign policy with an Aust...       1959  star
# 1  22348  RT @ESPNCFB: Fresno State with the KICK SIX ðŸ...       1992  star
# 2  13760  @samkimmins Would you be interested in meeting...       1983  star
# 3  44447  Incredible work by our law enforcement â€” fed...       1988  star
# 4  18632  RT @OP_kickers: @BryanGaul17 , einst @OFC_offi...       1989  star
#
#    gender occupation
# 0  female    science
# 1    male     sports
# 2    male     sports
# 3    male    manager
# 4    male     sports
# ...cleaning
# 107.89439940452576
# SPLIT/feed15.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed15
#       id                                               text  birthyear  fame  \
# 0  12587  RT @EdinburghJudo: Friday Squad girls, providi...       1986  star
# 1   2306  An elected Matthew Guy Liberal Nationals Gover...       1974  star
# 2  19951  YAAAAASSS this is awesome. Over here in Michig...       1986  star
# 3  13084  RT @EsquireClassic: Mortal Combat: https://t.c...       1976  star
# 4  22726  How often does our brain focus on whats wrong ...       1981  star
#
#    gender occupation
# 0  female     sports
# 1    male   politics
# 2  female     sports
# 3    male    creator
# 4    male     sports
# ...cleaning
# 87.20522546768188
# SPLIT/feed16.csv
# C:\Users\Tollef\Desktop\Spring2019\TextAnalysis\project\PAN-celebrity-profiling\data\SPLIT\feed16
#       id                                               text  birthyear  fame  \
# 0  13053  RT @sinnfeinireland: Sinn FÃ©in reps @SeanCrow...       1954  star
# 1  30102  All the best @BrandonVincent! It was a pleasur...       1987  star
# 2  41565  Finished first marathon! #hurting #melbmara #l...       1946  star
# 3    367  Congratulations to all #Solvay Award laureates...       1958  star
# 4  41153  RT @OliviaBValainis: A bit of rain won't dampe...       1962  star
#
#   gender    occupation
# 0   male      politics
# 1   male        sports
# 2   male       manager
# 3   male  professional
# 4   male      politics
# ...cleaning
# 45.78289341926575
